# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from scipy.special import expit as sigmoid
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import Ridge, LinearRegression

# %%
from utils import DataHandler
from ESN import EchoStateNetwork
from reservoirs import CPRC, GBPermanents

# %%
# X, Y = DataHandler().load_dataset('narma', n_samples = 1000, window_size=4, plot=True)
X, Y, Y_ = DataHandler().load_dataset('mixed_waves',n=10, total_points = 2000, window_size=8, plot=True, seed = 58)

# %%
train_size = 1500  # Training set size
window_size = 4
# Split into training and testing sets
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = Y[:train_size], Y[train_size:]

# %%
X_test[2]
# Out:
# array([ 0.5,  0.5,  0.5, -0.5, -0.5, -0.5, -0.5, -0.5])

# %%
dim=len(X_train[0])
cprc = CPRC(dim=dim, execution_mode='simulation', shot_percentage = 20)
esn = EchoStateNetwork(
    reservoir=cprc, 
    dim=dim, 
    regularization=1e-6, 
    alpha=0.8, 
    show_progress=True, 
    approach='time-multiplexing', # 'feedback', or 'time-multiplexing'
    model_type='ridge'  # Options: 'ridge', 'lasso', 'linear', 'svr'
)

# %%
esn.fit(X_train, y_train)
# Out:
# Training Progress: 100%|██████████████| 1500/1500 [00:10<00:00, 139.59 sample/s]

# %%
predictions = esn.predict(X_test)
# print(predictions)
# Out:
# Prediction Progress: 100%|██████████████| 492/492 [00:03<00:00, 134.58 sample/s]

# %%
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f"Quantum ESN RMSE: {rmse:.4f}")
a = 0
b = 150
# Plot Predictions
plt.plot(y_test[a:a+b], label="True")
plt.plot(predictions[a:a+b], label="Quantum ESN Pred")
plt.title("Quantum ESN Predictions with Optical Reservoir Computing")
plt.legend()
plt.show()
# Out:
# Quantum ESN RMSE: 0.2719

# %%
n = 10 
m = 5 
initial_input = X_train[-1]  

future_predictions = esn.predict_next_n_trained(X_test=X_test, initial_input=initial_input, n=n, m=m)
print(future_predictions)
# Out:
# Sequential Prediction Progress: 100%|███████| 10/10 [00:00<00:00, 134.74 step/s]
# [ 0.94248695  0.77589654  0.89749908  1.89685604  0.22750649  0.77589654
#   0.97817837 -0.16542412 -0.68541098  2.75243775]

# %%
l = []
s=0
for i in range(1,2019):
    a = np.floor(np.sqrt(i))
    l.append(a)
    s+=a
print(s)
# Out:
# 59466.0

# %%
# sum of squares 1/6 * n*(n+1)*(2n+1)
(1/6)*44*45*89
# Out:
# 29370.0

# %%
((45**2)*44)-(6*44)
# Out:
# 88836

# %%
88836-29370
# Out:
# 59466
