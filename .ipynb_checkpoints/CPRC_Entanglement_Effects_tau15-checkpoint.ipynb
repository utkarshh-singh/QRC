# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from scipy.special import expit as sigmoid
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import Ridge, LinearRegression

# %%
from utils import DataHandler
from ESN import ESNetwork, ClassicalRC
from ESN2 import EchoStateNetwork
from reservoirs import CPRC, GBPermanents
from circuits import CPCircuit

# %%
window_size = 20
n_samples = 1000
# X, Y = DataHandler().load_dataset('narma', n_samples = 1000, window_size=4, plot=True)
X, Y = DataHandler().load_dataset('mackey_glass', n_samples = n_samples, tau = 15, window_size=window_size,prediction_horizon=20, plot=True)

# %%
tr = 0.75
train_size = int(n_samples*tr)  # Training set size
# Split into training and testing sets
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = Y[:train_size], Y[train_size:]

# %%
itr = 50
a= -1.4746251231135765
b = 1.47
vals = np.linspace(a,b,itr)

# %%
mserror2 =[]
for i in range(itr):
    dim=len(X_train[0])
#     CP_params = [
#                 -np.pi/3, 
#                 np.pi/6, 
#                 -np.pi/9, 
#                 np.pi/7, 
#                 i*np.pi/160, 
#                 -np.pi/7
#             ]
    CP_params = [vals[i], np.pi/7, -np.pi/3, 7*np.pi/7,np.pi/9, -np.pi/7]
    cprc = CPRC(dim=dim, execution_mode='simulation', CP_params=CP_params, kernel = True) #simulation
    esn = ESNetwork(
        reservoir=cprc, 
        dim=dim, 
        regularization=1e-6, 
        alpha=1, 
        show_progress=True, 
        approach='feedback', # 'feedback', or 'time-multiplexing'
        model_type='ridge',  # Options: 'ridge', 'lasso', 'linear', 'svr', 'svc'
        limit = 0.6,
        cpk=True)
    esn.fit(X_train, y_train)
    predictions = esn.predict(X_test)
    rmse = mean_squared_error(y_test, predictions)
    mserror2.append(rmse)
    # print(predictions)
# Out:
# Training Progress: 100%|█████████████████| 750/750 [02:13<00:00,  5.61 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:35<00:00,  5.91 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:14<00:00,  5.59 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.69 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:13<00:00,  5.62 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.75 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:13<00:00,  5.61 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:37<00:00,  5.67 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:15<00:00,  5.54 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.70 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:14<00:00,  5.57 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.83 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:13<00:00,  5.62 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.70 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:17<00:00,  5.47 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.75 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:12<00:00,  5.64 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:35<00:00,  5.83 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:11<00:00,  5.69 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.74 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:12<00:00,  5.67 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.80 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:10<00:00,  5.74 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.69 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:13<00:00,  5.62 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.75 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:11<00:00,  5.69 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.73 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:10<00:00,  5.74 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.71 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:09<00:00,  5.79 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.70 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:12<00:00,  5.67 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:35<00:00,  5.85 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:13<00:00,  5.62 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.71 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:11<00:00,  5.70 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.72 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:13<00:00,  5.63 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.69 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:10<00:00,  5.74 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.75 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:07<00:00,  5.86 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.69 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:09<00:00,  5.78 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:37<00:00,  5.55 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:12<00:00,  5.65 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:37<00:00,  5.65 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:11<00:00,  5.69 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:37<00:00,  5.66 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:12<00:00,  5.64 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:38<00:00,  5.45 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:14<00:00,  5.59 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:39<00:00,  5.32 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:13<00:00,  5.62 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:35<00:00,  5.89 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:15<00:00,  5.52 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.76 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:14<00:00,  5.60 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:37<00:00,  5.64 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:14<00:00,  5.57 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.81 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:15<00:00,  5.53 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.82 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:16<00:00,  5.50 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:37<00:00,  5.60 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:14<00:00,  5.59 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:35<00:00,  5.86 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:14<00:00,  5.60 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.69 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:13<00:00,  5.62 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:37<00:00,  5.62 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:19<00:00,  5.37 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:37<00:00,  5.56 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:17<00:00,  5.44 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:38<00:00,  5.50 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:17<00:00,  5.44 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:37<00:00,  5.58 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:14<00:00,  5.58 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:37<00:00,  5.65 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:17<00:00,  5.46 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.68 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:16<00:00,  5.50 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:37<00:00,  5.63 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:16<00:00,  5.51 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:39<00:00,  5.32 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:14<00:00,  5.56 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:45<00:00,  4.67 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:15<00:00,  5.53 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:37<00:00,  5.61 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:16<00:00,  5.51 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:37<00:00,  5.59 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:14<00:00,  5.57 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:37<00:00,  5.55 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:15<00:00,  5.55 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:36<00:00,  5.76 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:15<00:00,  5.52 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:33<00:00,  6.36 sample/s]
# Training Progress: 100%|█████████████████| 750/750 [02:00<00:00,  6.20 sample/s]
# Prediction Progress: 100%|███████████████| 210/210 [00:31<00:00,  6.61 sample/s]

# %%
# CP_params = [-np.pi/3, i*np.pi/160, -np.pi/9, np.pi/7, np.pi/9, -np.pi/7]
param_values = [i for i in range(len(vals))]
plt.figure(figsize=(8, 5))
plt.plot(param_values, mserror2, marker='o', linestyle='-')
plt.xlabel("1st Parameter in CP_params (radians)")
plt.ylabel("Mean Squared Error")
plt.title("Performance of Quantum Reservoir vs Parameter Sweep")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
tau=15
df = pd.DataFrame([mserror2], columns=[f"mse_{i}" for i in range(len(mserror2))])
df.insert(0, "tau", tau) 
df.to_csv(f"mse_tau_{tau}.csv", index=False)
