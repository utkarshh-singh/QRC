# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from scipy.special import expit as sigmoid
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import Ridge, LinearRegression

# %%
from utils import DataHandler
from ESN import ESNetwork
from reservoirs import CPRC
from backend import QuantumBackendSelector

# %%
selector = QuantumBackendSelector(use_simulation=False, provider="IBMQ", 
                                  ibmq_token="08c051f22a4ffff00f5ff10d115109744a167d96680e05a22399300f89764b8cd986afdf77de4915a44886da1de734d619bc6fed6101e50dfc96b00db5026c86",
                                  ibmq_instance = 'ibm-q/open/main',
                                  backend_name = 'ibm_kyiv')
# Out:
# Do you want to use a fake backend simulation? (yes/no): no
# Using real IBMQ backend ibm_kyiv.

# %%
backend_info = selector.get_backend_info()

# %%
sampler = backend_info[0]

# %%
window_size = 10
n_samples = 500
# X, Y = DataHandler().load_dataset('narma', n_samples = 1000, window_size=4, plot=True)
X, Y = DataHandler().load_dataset('mackey_glass', n_samples = n_samples, tau = 12, window_size=window_size,prediction_horizon=20, plot=False)

# %%
tr = 0.75
train_size = int(n_samples*tr)  # Training set size
# Split into training and testing sets
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = Y[:train_size], Y[train_size:]

# %%
len(X_train)#[2]
# Out:
# 375

# %%
dim=len(X_train[0])
CP_params = [-np.pi/3, 23*np.pi/160, -np.pi/9, np.pi/7, 23*np.pi/160, -np.pi/7]
cprc = CPRC(dim=dim, execution_mode='real_device', CP_params=CP_params, backend = sampler, kernel = True)
esn = ESNetwork(
    reservoir=cprc, 
    dim=dim, 
    regularization=1e-6, 
    alpha=1, 
    show_progress=True, 
    approach='feedback', # 'feedback', or 'time-multiplexing'
    model_type='ridge',  # Options: 'ridge', 'lasso', 'linear', 'svr', 'svc'
    limit = 0.6,
    cpk = True
)

# %%
esn.fit(X_train, y_train)
# Out:
# Training Progress:  59%|███████▋     | 223/375 [1:33:50<1:07:07, 26.50s/ sample]/Users/utkarshsingh/miniforge3/envs/qml/lib/python3.9/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:874: UserWarning: The backend ibm_kyiv currently has a status of internal.
# Training Progress:  90%|█████████████▌ | 339/375 [2:18:59<13:37, 22.70s/ sample]/Users/utkarshsingh/miniforge3/envs/qml/lib/python3.9/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:903: UserWarning: Your current pending jobs are estimated to consume 2.214050497089614 quantum seconds, but you only have 2 quantum seconds left in your monthly quota; therefore, it is likely this job will be canceled
# Training Progress:  91%|█████████████▌ | 340/375 [2:19:21<13:00, 22.30s/ sample]/Users/utkarshsingh/miniforge3/envs/qml/lib/python3.9/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:903: UserWarning: Your current pending jobs are estimated to consume 2.1039817804508294 quantum seconds, but you only have 1 quantum seconds left in your monthly quota; therefore, it is likely this job will be canceled
# Training Progress:  91%|█████████████▋ | 341/375 [2:19:58<13:57, 24.63s/ sample]
# ---------------------------------------------------------------------------
# IBMRuntimeError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 esn.fit(X_train, y_train)
#
# File ~/QRC/ESN.py:290, in ESNetwork.fit(self, X, Y, load_saved)
#     287 x = np.array(x, dtype=np.float32)
#     288 modified_input = self._apply_feedback(x)
# --> 290 quantum_state = self.reservoir.compute(modified_input)
#     291 quantum_states.append(self._process_quantum_state(quantum_state))
#     293 if self.approach == 'feedback':
#
# File ~/QRC/utils.py:140, in ReservoirWrapper.compute(self, x)
#     138     return self.function.Probs(x, **self.kwargs)
#     139 elif isinstance(self.function, CPRC):
# --> 140     return self.function.qc_func(x)
#     141 elif isinstance(self.function, ClassicalReservoir):
#     142     return self.function.compute(x)
#
# File ~/QRC/reservoirs.py:199, in CPRC.qc_func(self, x)
#     197     return self._simulate_with_noise(qc)
#     198 elif self.execution_mode == 'real_device':
# --> 199     return self._run_on_real_device(qc, fake_simulation=False)
#     200 elif self.execution_mode == 'fake_simulation':
#     201     return self._run_on_real_device(qc, fake_simulation=True)
#
# File ~/QRC/reservoirs.py:159, in CPRC._run_on_real_device(self, qc, fake_simulation)
#     157             sampler = Sampler2(backend=self.backend)
#     158             sampler.options.default_shots = self.shots
# --> 159             job = sampler.run([qc])
#     160 #             print(f"Job ID is {job.job_id()}")
#     161             result = job.result()
#
# File ~/miniforge3/envs/qml/lib/python3.9/site-packages/qiskit_ibm_runtime/sampler.py:159, in SamplerV2.run(self, pubs, shots)
#     155 coerced_pubs = [SamplerPub.coerce(pub, shots) for pub in pubs]
#     157 validate_classical_registers(coerced_pubs)
# --> 159 return self._run(coerced_pubs)
#
# File ~/miniforge3/envs/qml/lib/python3.9/site-packages/qiskit_ibm_runtime/base_primitive.py:197, in BasePrimitiveV2._run(self, pubs)
#     194         runtime_options["instance"] = self._backend._instance
#     196 if isinstance(self._service, QiskitRuntimeService):
# --> 197     return self._service.run(
#     198         program_id=self._program_id(),
#     199         options=runtime_options,
#     200         inputs=primitive_inputs,
#     201         callback=options_dict.get("environment", {}).get("callback", None),
#     202         result_decoder=DEFAULT_DECODERS.get(self._program_id()),
#     203     )
#     205 return self._service._run(
#     206     program_id=self._program_id(),  # type: ignore[arg-type]
#     207     options=runtime_options,
#     208     inputs=primitive_inputs,
#     209 )
#
# File ~/miniforge3/envs/qml/lib/python3.9/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:908, in QiskitRuntimeService.run(self, program_id, inputs, options, callback, result_decoder, session_id, start_session)
#     906     if ex.status_code == 404:
#     907         raise RuntimeProgramNotFound(f"Program not found: {ex.message}") from None
# --> 908     raise IBMRuntimeError(f"Failed to run program: {ex}") from None
#     910 if response["backend"] and response["backend"] != qrt_options.get_backend_name():
#     911     backend = self.backend(name=response["backend"], instance=hgp_name)
#
# IBMRuntimeError: 'Failed to run program: \'403 Client Error: Forbidden for url: https://api.quantum.ibm.com/runtime/jobs. {"errors":[{"message":"Job create exceeds open plan job usage limits","code":4317,"solution":"Please wait until the beginning of next month to submit more jobs when your quota will reset.","more_info":"https://docs.quantum-computing.ibm.com/errors"}]}\''

# %%
import pickle
import numpy as np

# Load precomputed reservoir states
with open("cprc_recovery/reservoir_states.pkl", "rb") as f:
    recovered_states = pickle.load(f)

# Convert list of states into a matrix
reservoir_matrix = np.vstack(recovered_states)

# Confirm shape and alignment
assert reservoir_matrix.shape[0] == 340, f"Expected 340 states, got {reservoir_matrix.shape[0]}"
assert reservoir_matrix.shape[0] <= len(X_train), "Mismatch: more states than samples"

# Assign precomputed quantum states
esn.saved_quantum_states = reservoir_matrix

# Fit the model using only the corresponding part of X_train and y_train
esn.fit(X_train[:340], y_train[:340], load_saved=True)
# Out:
# Using previously saved quantum states.

# %%
with open("cprc_recovery/x_test_states.pkl", "rb") as f:
    x_test_states = pickle.load(f)

x_test_matrix = np.vstack(x_test_states)

# %%
# predictions = esn.predict(X_test[0:50])
predictions = esn.model.predict(x_test_matrix)
# print(predictions)

# %%
## read_device: ibm_kyiv
rmse = mean_squared_error(y_test[0:50], predictions)
print(f"Quantum ESN RMSE: {rmse:.4f}")
a = 0
b = 60
# Plot Predictions
plt.plot(y_test[a:a+b], label="True")
plt.plot(predictions[a:a+b], label="Quantum ESN Pred")
plt.title("Quantum ESN Predictions with Optical Reservoir Computing")
plt.legend()
plt.show()
# Out:
# Quantum ESN RMSE: 0.1509

# %%
from numpy.polynomial.polynomial import Polynomial

x = np.arange(len(predictions))
poly_fit = Polynomial.fit(x, predictions, deg=3)
y_poly = poly_fit(x)

plt.plot(y_test[:len(predictions)], label="True")
plt.plot(predictions, label="Quantum ESN Pred")
plt.plot(y_poly, label="Polynomial Fit (deg=3)", linestyle="--")
plt.legend()
plt.title("Quantum ESN Prediction with Polynomial Fit")
plt.show()

# %%
## fake Simulation
rmse = mean_squared_error(y_test, predictions)
print(f"Quantum ESN RMSE: {rmse:.4f}")
a = 0
b = 150
# Plot Predictions
plt.plot(y_test[a:a+b], label="True")
plt.plot(predictions[a:a+b], label="Quantum ESN Pred")
plt.title("Quantum ESN Predictions with Optical Reservoir Computing")
plt.legend()
plt.show()
# Out:
# Quantum ESN RMSE: 0.0289

# %%
## Exact Simulation
rmse = mean_squared_error(y_test, predictions)
print(f"Quantum ESN RMSE: {rmse:.4f}")
a = 0
b = 150
# Plot Predictions
plt.plot(y_test[a:a+b], label="True")
plt.plot(predictions[a:a+b], label="Quantum ESN Pred")
plt.title("Quantum ESN Predictions with Optical Reservoir Computing")
plt.legend()
plt.show()
# Out:
# Quantum ESN RMSE: 0.0000

# %%
# n = 20 
# m = 2 
# initial_input = X_test[-1]  
# future_predictions = esn.predict(X=None, X_test=X_test, initial_input=initial_input, n=n, m=m)
# print(future_predictions)

# %%
# next_predictions = future_predictions
# t_test = np.arange(len(y_test))  
# t_future = np.arange(len(y_test), len(y_test) + n) 
# plt.figure(figsize=(10, 5))
# plt.plot(t_test, y_test, label="True Values (y_test)", color="blue", linestyle="-")
# plt.plot(t_test, predictions, label="Predicted Values (Y_pred)", color="green", linestyle="--")
# plt.plot(t_future, next_predictions, label=f"Next {n} Predictions", color="red", linestyle="dotted")

# # Labels and legend
# plt.xlabel("Time Steps")
# plt.ylabel("Values")
# plt.title("ESN Predictions with Next n Steps")
# plt.legend()
# plt.grid(True)

# # Show plot
# plt.show()

# %%
# t_test = np.arange(n) 
# y_pred = future_predictions
# plt.figure(figsize=(10, 5))
# plt.plot(t_test, y_test[2:n+2], label="True Values (y_test)", color="blue", linestyle="-")
# plt.plot(t_test, y_pred, label="Predicted Values (y_pred)", color="green", linestyle="--")

# plt.xlabel("Time Steps")
# plt.ylabel("Values")
# plt.title("ESN Predictions with Next n Steps")
# plt.legend()
# plt.grid(True)
# plt.show()

# %%
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
y_pred_lr = lr_model.predict(X_test)

# Train Neural Network Regression Model
mlp_model = MLPRegressor(hidden_layer_sizes=(50,), activation='relu', max_iter=1000, random_state=42)
mlp_model.fit(X_train, y_train)
y_pred_mlp = mlp_model.predict(X_test)

# Evaluate Performance
mse_lr = mean_squared_error(y_test, y_pred_lr)
mse_mlp = mean_squared_error(y_test, y_pred_mlp)

# Plot results
plt.figure(figsize=(12, 5))
plt.plot(y_test[:200], label="True", linestyle="dashed", color="black")
plt.plot(y_pred_lr[:200], label="Linear Regression", color="blue")
plt.plot(y_pred_mlp[:200], label="Neural Network", color="red")
plt.legend()
plt.title(f"Prediction Performance (MSE - LR: {mse_lr:.4f}, MSE - MLP: {mse_mlp:.4f})")
plt.xlabel("Time Steps")
plt.ylabel("Value")
plt.show()

# Display MSE results
print(f"MSE for LR: {mse_lr}, MSE for MLP: {mse_mlp}")
# Out:
# MSE for LR: 0.005441321131543039, MSE for MLP: 0.01689332675942561

# %%
CRM = ClassicalRC(input_size=8, reservoir_size=100, spectral_radius=0.3, sparsity=0.2,noise=0.0001,use_reservoir=True)
CRM.train(X_train, y_train, model_type="ridge")

# %%
y_pred = CRM.predict(X_test)
mse = CRM.evaluate(X_test, y_test)
np.sqrt(mse)
# Out:
# 0.07010060702455953

# %%
# CRM.plot_predictions(y_test, y_pred, title="Reservoir Computing Prediction")

# %%
CRM.compute_reservoir_properties()
# Out:
# Reservoir Properties:
# - Spectral Radius (Desired): 0.3
# - Spectral Radius (Actual): 0.3000
# - Sparsity (Desired): 0.2
# - Sparsity (Actual): 0.8033

# %%
CRM.check_properties(X, Y, X_train, y_train, X_test, y_test, threshold =5e-2, plot=True)
# Out:
# Reservoir Property Evaluations:
# - Reservoir Task RMSE: 0.0599
# - Memory Capacity: 9.8951
# - Verify Echo State Property (ESP): False
# - Largest Lyapunov Exponent: 0.0619
# - Separation Property: -0.0130

# %%
RegressorM = ClassicalRC(input_size=8, reservoir_size=100, use_reservoir=False)
RegressorM.train(X_train, y_train, model_type="linear")

# %%
y_pred_reg = RegressorM.predict(X_test)
mse_reg = RegressorM.evaluate(X_test, y_test)
np.sqrt(mse_reg)
# Out:
# 0.09860154050097969

# %%
RegressorM.plot_predictions(y_test, y_pred_reg, title="Regression Model Prediction")

# %%
import numpy as np
import scipy.linalg
import matplotlib.pyplot as plt

# 1. Largest Lyapunov Exponent (LLE)
def lyapunov_exponent(reservoir_update, x0, u_sequence, epsilon=1e-5, steps=1000):
    """
    Computes the largest Lyapunov exponent for a given reservoir.
    :param reservoir_update: Function defining reservoir state update x_{t+1} = f(x_t, u_t)
    :param x0: Initial state of the reservoir
    :param u_sequence: Input sequence applied to reservoir
    :param epsilon: Small perturbation size
    :param steps: Number of time steps to evaluate
    """
    x1 = x0.copy()
    x2 = x0 + epsilon  # Slightly perturbed initial condition
    lyapunov_sum = 0
    
    for t in range(steps):
        x1 = reservoir_update(x1, u_sequence[t])
        x2 = reservoir_update(x2, u_sequence[t])
        
        distance = np.linalg.norm(x2 - x1)
        lyapunov_sum += np.log(distance / epsilon)
        x2 = x1 + (x2 - x1) * (epsilon / distance)  # Normalize separation
    
    return lyapunov_sum / steps

# 2. Washout Test (State Convergence)
def washout_test(reservoir_update, x0, x0_prime, u_sequence, steps=1000):
    """
    Tests whether different initial conditions converge over time.
    :param reservoir_update: Reservoir update function
    :param x0: Initial state 1
    :param x0_prime: Initial state 2 (different)
    :param u_sequence: Input sequence
    :param steps: Number of steps to track
    """
    distances = []
    x1, x2 = x0.copy(), x0_prime.copy()
    
    for t in range(steps):
        x1 = reservoir_update(x1, u_sequence[t])
        x2 = reservoir_update(x2, u_sequence[t])
        distances.append(np.linalg.norm(x1 - x2))
    
    plt.plot(distances)
    plt.xlabel("Time Step")
    plt.ylabel("State Difference")
    plt.title("Washout Test - Convergence of States")
    plt.show()
    return distances

# 3. Spectral Radius Approximation (for Linear Reservoirs)
def spectral_radius(W):
    """
    Computes the spectral radius (largest eigenvalue magnitude) of a reservoir weight matrix.
    :param W: Reservoir weight matrix
    """
    eigenvalues = np.linalg.eigvals(W)
    return max(abs(eigenvalues))

# 4. Information Processing Capacity (Memory and Nonlinearity)
def compute_memory_capacity(reservoir_update, x0, input_sequence, delay=10):
    """
    Estimates how well the reservoir retains past inputs.
    :param reservoir_update: Reservoir update function
    :param x0: Initial state of the reservoir
    :param input_sequence: Input sequence
    :param delay: Number of steps to look back
    """
    memory_scores = []
    states = []
    
    x = x0.copy()
    for u in input_sequence:
        x = reservoir_update(x, u)
        states.append(x)
    states = np.array(states)
    
    for d in range(1, delay + 1):
        past_inputs = input_sequence[:-d]
        delayed_outputs = states[d:]
        corr = np.corrcoef(past_inputs, delayed_outputs[:, 0])[0, 1]  # Correlation with first state dimension
        memory_scores.append(corr)
    
    plt.plot(range(1, delay + 1), memory_scores)
    plt.xlabel("Delay")
    plt.ylabel("Memory Score")
    plt.title("Memory Capacity of Reservoir")
    plt.show()
    return sum(memory_scores)

# Example: Define a simple reservoir system
def example_reservoir_update(x, u):
    W = np.array([[0.8, 0.1], [-0.1, 0.9]])  # Example weight matrix
    return np.tanh(np.dot(W, x) + u)

# Running the tests
x0 = np.array([0.1, 0.2])
x0_prime = np.array([-0.2, 0.1])
u_sequence = np.random.randn(1000, 2)  # Random input sequence

lle = lyapunov_exponent(example_reservoir_update, x0, u_sequence)
print(f"Largest Lyapunov Exponent: {lle}")

washout_test(example_reservoir_update, x0, x0_prime, u_sequence)

sr = spectral_radius(np.array([[0.8, 0.1], [-0.1, 0.9]]))
print(f"Spectral Radius: {sr}")

mc = compute_memory_capacity(example_reservoir_update, x0, u_sequence[:, 0])
print(f"Memory Capacity Score: {mc}")
# Out:
# Largest Lyapunov Exponent: -0.9217778643439413
# Spectral Radius: 0.8544003745317531
# Memory Capacity Score: 0.8001785861396833
