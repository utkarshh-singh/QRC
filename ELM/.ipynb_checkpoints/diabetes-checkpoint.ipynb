# %%
from data import CleanNumericDatasets
from reservoirs import CPRC
from circuits import CPCircuit
from ELM import QuantumELM
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from utility import Evaluator

# %%
dim = 12
ds = CleanNumericDatasets(seed=3, scale=True)

Xc, yc = ds.get("breast_cancer", sample_size=400, feature_size=dim)
ds.info(print_out=True)

Xr, yr = ds.get("diabetes", sample_size=300, feature_size=dim)
print(ds.info())
# Out:
# name: breast_cancer
# task: classification
# n_samples_requested: 400
# n_features_requested: 12
# n_samples_returned: 400
# n_features_returned: 12
# n_classes: 2
# feature_transform: selectkbest
# scaler: standard
# y_type: int64
# X_dtype: float32
# notes: Built-in clean numeric dataset from sklearn.datasets. Features adjusted via SelectKBest or PCA (capped if requested > native).
# {'name': 'diabetes', 'task': 'regression', 'n_samples_requested': 300, 'n_features_requested': 12, 'n_samples_returned': 300, 'n_features_returned': 10, 'n_classes': None, 'feature_transform': 'pca(capped)', 'scaler': 'standard', 'y_type': 'float64', 'X_dtype': 'float32', 'notes': 'Built-in clean numeric dataset from sklearn.datasets. Features adjusted via SelectKBest or PCA (capped if requested > native).'}

# %%
X_train, X_test, y_train, y_test = train_test_split(Xc, yc, test_size=0.2, random_state=42)

# %%
CP_params = [-np.pi/3, np.pi/6, -np.pi/9, np.pi/7, np.pi/9, -np.pi/7]
cprc = CPRC(dim=dim, execution_mode='simulation', CP_params=CP_params, kernel = True)

# %%
elm = QuantumELM(
        reservoir=cprc, 
        regularization=1e-3, 
        show_progress=True, 
        model_type='ridge_classifier',  # Options: 'ridge', 'lasso', 'linear', 'svr', 'svc',  or "ridge_classifier","logreg", "svc" for classification
        )
elm.fit(X_train, y_train)
# Out:
# ELM feature extraction: 100%|████████████| 320/320 [00:04<00:00, 72.55 sample/s]

# %%
predictions = elm.predict(X_test)
rmse = mean_squared_error(y_test, predictions)
print("RMSE:", rmse)
# Out:
# ELM feature extraction: 100%|██████████████| 80/80 [00:01<00:00, 70.48 sample/s]
# RMSE: 0.05

# %%
Evaluator(y_test, predictions).evaluate()
# Out:
# Evaluation Metrics:
# Accuracy:  0.95
# Recall:  0.9615384615384616
# F1 Score:  0.9615384615384616
# Precision:  0.9615384615384616
# Matthews Correlation Coefficient:  0.8901098901098901
#
# Confusion Matrix:
# TN, FP, FN, TP
# [26  2  2 50]
